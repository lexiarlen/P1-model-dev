# %%
import numpy as np 
import xarray as xr
import matplotlib.pyplot as plt

# %%
arr = np.load('/scratch/groups/earlew/arlenlex/P1-model-dev/size_effect/data/ensemble_final/figures/N003496Dump_s_shear_array.npy')

# %%
plt.plot(arr)

# %%
arr
# Out:
# array([5.87897835e-10, 9.37847984e+01, 1.82968289e+02, 2.72281048e+02,
#        3.62361580e+02, 4.53092353e+02, 5.44093296e+02, 6.35062438e+02,
#        7.25926268e+02, 8.16723685e+02, 9.07479891e+02, 9.98220970e+02,
#        1.08899756e+03, 1.17983889e+03, 1.27071872e+03, 1.36158583e+03,
#        1.45241457e+03, 1.54321952e+03, 1.63403025e+03, 1.72485862e+03,
#        1.81569103e+03, 1.90650189e+03, 1.99727523e+03, 2.08801113e+03,
#        2.17872404e+03, 2.26943227e+03, 2.36015073e+03, 2.45088892e+03,
#        2.54165231e+03, 2.63244524e+03, 2.72327481e+03, 2.81414913e+03,
#        2.90507517e+03, 2.99605489e+03, 3.08708179e+03, 3.17814364e+03,
#        3.26922640e+03, 3.36031663e+03, 3.45140300e+03, 3.54247539e+03,
#        3.63352536e+03, 3.72454534e+03, 3.81553006e+03, 3.90647809e+03,
#        3.99739294e+03, 4.08828004e+03, 4.17914698e+03, 4.26999906e+03,
#        4.36084005e+03, 4.45167135e+03, 4.54249178e+03, 4.63330003e+03,
# ...

# %%
len(arr)
# Out:
# 505
